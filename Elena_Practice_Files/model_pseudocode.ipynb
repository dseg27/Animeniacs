# %%
# Install and import packages into mlenv enviroment 
from sentence_transformers import SentenceTransformer, util
import pandas as pd

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
# Import cleaned data csvs
file_anime = '../Final Resources/cleaned_anime.csv'
file_la = '../Final Resources/cleaned_live_actions.csv'

# %%
# Create dfs
anime_df = pd.read_csv(file_anime, index_col=0) # add index_col=0 so that there aren't 2 index columns!
la_df = pd.read_csv(file_la, index_col=0)

# %%
# Make a list of anime descriptions from df
anime_desc = anime_df['synopsis'].tolist()

# %%
# Make a list of netflix, hulu, amazon prime, disney+ descriptions
la_desc = la_df['description'].tolist()

# %%
# make a list of the index of rows that are missing descriptions
strings = []
floats = []
for i in range(len(anime_desc)):
    if type(anime_desc[i]) == str:
        strings.append(i)
    else:
        floats.append(i)


len(floats)
# Out:
# 0

# %%
# make a list of the index of rows that are missing descriptions
string = []
floaters = []
for i in range(len(la_desc)):
    if type(la_desc[i]) == str:
        strings.append(i)
    else:
        floaters.append(i)


len(floaters)
# Out:
# 0

# %%
len(la_desc)
# Out:
# 21784

# %%
len(anime_desc)
# Out:
# 5111

# %%
# Encode descriptions from both lists
anime_embedding = model.encode(anime_desc) # Encoding the anime list

# %%
type(anime_embedding)
# Out:
# numpy.ndarray

# %%
column_series = pd.Series(anime_embedding)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23584/3585205094.py in <module>
# ----> 1 column_series = pd.Series(anime_embedding)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     437                     data = data.copy()
#     438             else:
# --> 439                 data = sanitize_array(data, index, dtype, copy)
#     440
#     441                 manager = get_option("mode.data_manager")
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     574                 subarr = maybe_infer_to_datetimelike(subarr)
#     575
# --> 576     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     577
#     578     if isinstance(subarr, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     625             if allow_2d:
#     626                 return result
# --> 627             raise ValueError("Data must be 1-dimensional")
#     628         if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     629             # i.e. PandasDtype("O")
#
# ValueError: Data must be 1-dimensional

# %%
anime_embedding_df = pd.DataFrame(anime_embedding)
anime_embedding_df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.080896  0.081521  0.024639 -0.022273 -0.024698 -0.013718  0.044134
# 1 -0.073111 -0.014546  0.009811  0.016464 -0.024401  0.057630  0.045597
# 2 -0.069815  0.049462  0.002211  0.026143  0.017300 -0.049455  0.046423
# 3 -0.116074  0.059125 -0.009722 -0.019543 -0.049341 -0.033883  0.051601
# 4 -0.113074  0.056182 -0.065571  0.069393 -0.059860  0.009886  0.022183
#
#         7         8         9    ...       374       375       376       377  \
# 0  0.030280 -0.033405  0.055939  ... -0.055394  0.071931 -0.046239 -0.001261
# 1 -0.057840  0.012522 -0.041396  ...  0.027330  0.015306 -0.027152  0.042169
# 2  0.010373  0.023637 -0.033681  ...  0.055453  0.005420  0.010394  0.062388
# 3 -0.032328  0.009772 -0.006919  ... -0.043402 -0.034193 -0.055788 -0.006170
# 4 -0.060608  0.021883  0.013101  ...  0.013625 -0.016732 -0.080794 -0.033309
#
#         378       379       380       381       382       383
# 0 -0.007824  0.006315  0.126777 -0.066777 -0.097394  0.070937
# 1 -0.085612 -0.011866  0.028435 -0.010502 -0.008784  0.040417
# 2 -0.098413  0.097373  0.047905  0.014281 -0.004877 -0.025122
# 3 -0.041296  0.014373  0.101554  0.008523  0.037134 -0.123190
# 4  0.036567  0.061300  0.046308  0.000651 -0.012857 -0.042470
#
# [5 rows x 384 columns]

# %%
la_embedding = model.encode(la_desc) # Encoding the netflix list

# %%
# Add encodings as a column append for each list

### This block will return error: ###

#la_df['la_embeddings'] = la_embedding
#anime_df['anime_embeddings'] = anime_embedding
#anime_df.head()

# %% [markdown]
# Adding the embeddings for each description will not be very efficient: each embedding is ~400 numbers in a list. Pivot plan. Run comparisons, pull top 5 most simialar shows instead.

# %%
practice_la_embed= la_embedding[0:20]
practice_anime_embed = anime_embedding[0:10]

# %%
# Compute cosine similarities
cos_sim = util.cos_sim(practice_la_embed, practice_anime_embed)
cos_sim
# Out:
# tensor([[ 0.0485,  0.2290,  0.2079,  0.1554,  0.2385,  0.1965,  0.1879,  0.2988,
#           0.2498,  0.0855],
#         [ 0.1681,  0.1254,  0.1798,  0.0575,  0.1273,  0.0204,  0.2033,  0.1580,
#           0.2727,  0.1083],
#         [ 0.2328,  0.1589,  0.2318,  0.2531,  0.1374,  0.2239,  0.1444,  0.3077,
#           0.2273,  0.3492],
#         [ 0.0453,  0.0412,  0.1235,  0.1116,  0.0797,  0.1347,  0.1202,  0.1185,
#           0.1120,  0.1209],
#         [ 0.2692,  0.1526,  0.1197, -0.0107,  0.1000,  0.2105,  0.1939,  0.1550,
#           0.4049,  0.1125],
#         [ 0.0446,  0.1250,  0.1993,  0.0797,  0.0887,  0.3739,  0.3397,  0.2987,
#           0.2851,  0.1897],
#         [ 0.1878,  0.1236,  0.2373,  0.1676,  0.1393,  0.1592,  0.3691,  0.1891,
#           0.2991,  0.2184],
#         [ 0.0329,  0.0933,  0.1938,  0.1096,  0.0907,  0.1464,  0.1703,  0.1733,
#           0.1481,  0.1881],
#         [ 0.1814,  0.0475,  0.0274,  0.0819, -0.0396,  0.0139,  0.0846,  0.0386,
#           0.0354,  0.1515],
#         [ 0.0070,  0.0871,  0.1567,  0.0753,  0.1149,  0.0477,  0.2814,  0.1770,
#           0.1083, -0.0139],
#         [ 0.1268,  0.0154,  0.1039,  0.1554,  0.0765,  0.1776,  0.0169,  0.1308,
#           0.1089,  0.2607],
#         [ 0.1054,  0.1956,  0.2072,  0.0831,  0.1014,  0.2445,  0.2014,  0.2176,
#           0.2667,  0.2058],
#         [ 0.1327,  0.0625,  0.1836,  0.0880,  0.1828,  0.2276,  0.2359,  0.3932,
#           0.2042,  0.1433],
#         [ 0.2312,  0.1467,  0.1806,  0.0530,  0.0395,  0.0977,  0.2995,  0.1460,
#           0.2799,  0.1504],
#         [ 0.0664,  0.0306,  0.2064,  0.0487,  0.1074,  0.1742,  0.0830,  0.1758,
#           0.2115,  0.2220],
#         [ 0.0975,  0.1068,  0.0457,  0.0889, -0.0453,  0.0362, -0.0042,  0.0210,
#           0.2104,  0.1129],
#         [ 0.0653,  0.0383,  0.1271,  0.1423,  0.0117,  0.0642,  0.0787,  0.1113,
#           0.2211,  0.1907],
#         [ 0.0731,  0.1396,  0.1067,  0.1370,  0.0918,  0.0616,  0.3050,  0.3002,
#           0.1771,  0.1593],
#         [ 0.0830,  0.0295,  0.2188,  0.0764,  0.1419,  0.1308,  0.3286,  0.2857,
#           0.2408,  0.1547],
#         [ 0.0585, -0.0149,  0.1912,  0.1569,  0.0727,  0.1316,  0.1276,  0.1908,
#           0.1527,  0.2551]])

# %%
type(cos_sim)
# Out:
# torch.Tensor

# %%
cos_sim[0]
# Out:
# tensor([0.0485, 0.2290, 0.2079, 0.1554, 0.2385, 0.1965, 0.1879, 0.2988, 0.2498,
#         0.0855])

# %%
practice_la_titles = la_df["title"][0:20]

# %%
## This is just to visualize the tensor so I can check for loop below more easily :)
practice_anime_titles = anime_df["title"][0:10]
practice_la_titles = la_df["title"][0:20]
pract_cossim_df = pd.DataFrame(cos_sim).astype("float")
pract_cossim_df = pract_cossim_df.set_axis(practice_anime_titles, axis=1, inplace=False)
pract_cossim_df= pract_cossim_df.set_index(practice_la_titles, drop=False)
pract_cossim_df
# Out:
# title                                               Haikyuu!! Second Season  \
# title
# Dick Johnson Is Dead                                               0.048462
# Blood & Water                                                      0.168082
# Ganglands                                                          0.232796
# Jailbirds New Orleans                                              0.045336
# Kota Factory                                                       0.269244
# Midnight Mass                                                      0.044584
# My Little Pony: A New Generation                                   0.187775
# Sankofa                                                            0.032912
# The Great British Baking Show                                      0.181354
# The Starling                                                       0.007047
# Vendetta: Truth, Lies and The Mafia                                0.126792
# Bangkok Breaking                                                   0.105373
# Je Suis Karl                                                       0.132666
# Confessions of an Invisible Girl                                   0.231238
# Crime Stories: India Detectives                                    0.066404
# Dear White People                                                  0.097456
# Europe's Most Dangerous Man: Otto Skorzeny in S...                 0.065312
# Falsa identidad                                                    0.073099
# Intrusion                                                          0.083049
# Jaguar                                                             0.058543
#
# title                                               Shigatsu wa Kimi no Uso  \
# title
# Dick Johnson Is Dead                                               0.228976
# Blood & Water                                                      0.125389
# Ganglands                                                          0.158869
# Jailbirds New Orleans                                              0.041186
# Kota Factory                                                       0.152552
# Midnight Mass                                                      0.125038
# My Little Pony: A New Generation                                   0.123587
# Sankofa                                                            0.093252
# The Great British Baking Show                                      0.047517
# The Starling                                                       0.087087
# Vendetta: Truth, Lies and The Mafia                                0.015401
# Bangkok Breaking                                                   0.195647
# Je Suis Karl                                                       0.062503
# Confessions of an Invisible Girl                                   0.146666
# Crime Stories: India Detectives                                    0.030628
# Dear White People                                                  0.106761
# Europe's Most Dangerous Man: Otto Skorzeny in S...                 0.038269
# Falsa identidad                                                    0.139598
# Intrusion                                                          0.029469
# Jaguar                                                            -0.014940
#
# title                                               Made in Abyss  \
# title
# Dick Johnson Is Dead                                     0.207877
# Blood & Water                                            0.179788
# Ganglands                                                0.231843
# Jailbirds New Orleans                                    0.123505
# Kota Factory                                             0.119683
# Midnight Mass                                            0.199332
# My Little Pony: A New Generation                         0.237272
# Sankofa                                                  0.193839
# The Great British Baking Show                            0.027430
# The Starling                                             0.156699
# Vendetta: Truth, Lies and The Mafia                      0.103907
# Bangkok Breaking                                         0.207235
# Je Suis Karl                                             0.183551
# Confessions of an Invisible Girl                         0.180641
# Crime Stories: India Detectives                          0.206364
# Dear White People                                        0.045731
# Europe's Most Dangerous Man: Otto Skorzeny in S...       0.127140
# Falsa identidad                                          0.106718
# Intrusion                                                0.218834
# Jaguar                                                   0.191162
#
# title                                               Fullmetal Alchemist: Brotherhood  \
# title
# Dick Johnson Is Dead                                                        0.155418
# Blood & Water                                                               0.057479
# Ganglands                                                                   0.253069
# Jailbirds New Orleans                                                       0.111594
# Kota Factory                                                               -0.010675
# Midnight Mass                                                               0.079701
# My Little Pony: A New Generation                                            0.167637
# Sankofa                                                                     0.109600
# The Great British Baking Show                                               0.081923
# The Starling                                                                0.075254
# Vendetta: Truth, Lies and The Mafia                                         0.155436
# Bangkok Breaking                                                            0.083099
# Je Suis Karl                                                                0.088035
# Confessions of an Invisible Girl                                            0.053002
# Crime Stories: India Detectives                                             0.048715
# Dear White People                                                           0.088913
# Europe's Most Dangerous Man: Otto Skorzeny in S...                          0.142315
# Falsa identidad                                                             0.136958
# Intrusion                                                                   0.076410
# Jaguar                                                                      0.156864
#
# title                                               Kizumonogatari III: Reiketsu-hen  \
# title
# Dick Johnson Is Dead                                                        0.238541
# Blood & Water                                                               0.127291
# Ganglands                                                                   0.137395
# Jailbirds New Orleans                                                       0.079721
# Kota Factory                                                                0.099996
# Midnight Mass                                                               0.088700
# My Little Pony: A New Generation                                            0.139279
# Sankofa                                                                     0.090696
# The Great British Baking Show                                              -0.039601
# The Starling                                                                0.114919
# Vendetta: Truth, Lies and The Mafia                                         0.076479
# Bangkok Breaking                                                            0.101361
# Je Suis Karl                                                                0.182798
# Confessions of an Invisible Girl                                            0.039498
# Crime Stories: India Detectives                                             0.107398
# Dear White People                                                          -0.045296
# Europe's Most Dangerous Man: Otto Skorzeny in S...                          0.011678
# Falsa identidad                                                             0.091797
# Intrusion                                                                   0.141874
# Jaguar                                                                      0.072664
#
# title                                               Mob Psycho 100 II  \
# title
# Dick Johnson Is Dead                                         0.196550
# Blood & Water                                                0.020444
# Ganglands                                                    0.223872
# Jailbirds New Orleans                                        0.134749
# Kota Factory                                                 0.210451
# Midnight Mass                                                0.373918
# My Little Pony: A New Generation                             0.159210
# Sankofa                                                      0.146372
# The Great British Baking Show                                0.013864
# The Starling                                                 0.047746
# Vendetta: Truth, Lies and The Mafia                          0.177618
# Bangkok Breaking                                             0.244543
# Je Suis Karl                                                 0.227603
# Confessions of an Invisible Girl                             0.097651
# Crime Stories: India Detectives                              0.174210
# Dear White People                                            0.036218
# Europe's Most Dangerous Man: Otto Skorzeny in S...           0.064223
# Falsa identidad                                              0.061586
# Intrusion                                                    0.130751
# Jaguar                                                       0.131625
#
# title                                               Sen to Chihiro no Kamikakushi  \
# title
# Dick Johnson Is Dead                                                     0.187894
# Blood & Water                                                            0.203260
# Ganglands                                                                0.144429
# Jailbirds New Orleans                                                    0.120208
# Kota Factory                                                             0.193913
# Midnight Mass                                                            0.339699
# My Little Pony: A New Generation                                         0.369115
# Sankofa                                                                  0.170312
# The Great British Baking Show                                            0.084615
# The Starling                                                             0.281396
# Vendetta: Truth, Lies and The Mafia                                      0.016873
# Bangkok Breaking                                                         0.201404
# Je Suis Karl                                                             0.235860
# Confessions of an Invisible Girl                                         0.299472
# Crime Stories: India Detectives                                          0.083008
# Dear White People                                                       -0.004228
# Europe's Most Dangerous Man: Otto Skorzeny in S...                       0.078708
# Falsa identidad                                                          0.304961
# Intrusion                                                                0.328558
# Jaguar                                                                   0.127622
#
# title                                               Kimetsu no Yaiba  \
# title
# Dick Johnson Is Dead                                        0.298825
# Blood & Water                                               0.157965
# Ganglands                                                   0.307729
# Jailbirds New Orleans                                       0.118505
# Kota Factory                                                0.154989
# Midnight Mass                                               0.298685
# My Little Pony: A New Generation                            0.189125
# Sankofa                                                     0.173284
# The Great British Baking Show                               0.038641
# The Starling                                                0.176999
# Vendetta: Truth, Lies and The Mafia                         0.130786
# Bangkok Breaking                                            0.217589
# Je Suis Karl                                                0.393202
# Confessions of an Invisible Girl                            0.145965
# Crime Stories: India Detectives                             0.175813
# Dear White People                                           0.020961
# Europe's Most Dangerous Man: Otto Skorzeny in S...          0.111306
# Falsa identidad                                             0.300191
# Intrusion                                                   0.285679
# Jaguar                                                      0.190801
#
# title                                               Owarimonogatari 2nd Season  \
# title
# Dick Johnson Is Dead                                                  0.249774
# Blood & Water                                                         0.272744
# Ganglands                                                             0.227324
# Jailbirds New Orleans                                                 0.112013
# Kota Factory                                                          0.404905
# Midnight Mass                                                         0.285089
# My Little Pony: A New Generation                                      0.299094
# Sankofa                                                               0.148090
# The Great British Baking Show                                         0.035353
# The Starling                                                          0.108321
# Vendetta: Truth, Lies and The Mafia                                   0.108858
# Bangkok Breaking                                                      0.266731
# Je Suis Karl                                                          0.204248
# Confessions of an Invisible Girl                                      0.279932
# Crime Stories: India Detectives                                       0.211502
# Dear White People                                                     0.210403
# Europe's Most Dangerous Man: Otto Skorzeny in S...                    0.221099
# Falsa identidad                                                       0.177109
# Intrusion                                                             0.240829
# Jaguar                                                                0.152663
#
# title                                               Code Geass: Hangyaku no Lelouch R2
# title
# Dick Johnson Is Dead                                                          0.085515
# Blood & Water                                                                 0.108262
# Ganglands                                                                     0.349184
# Jailbirds New Orleans                                                         0.120944
# Kota Factory                                                                  0.112476
# Midnight Mass                                                                 0.189656
# My Little Pony: A New Generation                                              0.218383
# Sankofa                                                                       0.188143
# The Great British Baking Show                                                 0.151465
# The Starling                                                                 -0.013935
# Vendetta: Truth, Lies and The Mafia                                           0.260678
# Bangkok Breaking                                                              0.205811
# Je Suis Karl                                                                  0.143275
# Confessions of an Invisible Girl                                              0.150414
# Crime Stories: India Detectives                                               0.221979
# Dear White People                                                             0.112932
# Europe's Most Dangerous Man: Otto Skorzeny in S...                            0.190707
# Falsa identidad                                                               0.159310
# Intrusion                                                                     0.154665
# Jaguar                                                                        0.255075

# %%
recs = []
# for each row in the cos_sim tensor
for i in range(len(cos_sim)):
    mydict={}

    # for each col in the row
    for x in range(len(cos_sim[i])):
        #assign title to the column from anime_df["title"][col#]
        mydict[anime_df["title"][x]] = cos_sim[i][x]

    # find the max value in all the columns
    top2 = sorted(mydict, key=mydict.get, reverse=True)[:2]
    recs.append(top2)

practice_la_df['recommended animes'] = recs

practice_la_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23584/2453875297.py in <module>
#       7     for x in range(len(cos_sim[i])):
#       8         #assign title to the column from anime_df["title"][col#]
# ----> 9         mydict[anime_df["title"][x]] = cos_sim[i][x]
#      10
#      11     # find the max value in all the columns
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
practice_la_df = la_df[0:20]

# %%
print(cos_sim[0][0], anime_df["title"][0])
print(cos_sim[0][1], anime_df["title"][1])
print(cos_sim[0][2], anime_df["title"][2])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._maybe_get_bool_indexer()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine._unpack_bool_indexer()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23584/3210543611.py in <module>
# ----> 1 print(cos_sim[0][0], anime_df["title"][0])
#       2 print(cos_sim[0][1], anime_df["title"][1])
#       3 print(cos_sim[0][2], anime_df["title"][2])
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0

# %%
len(cos_sim)
# Out:
# 20

# %%
len(cos_sim[0])
# Out:
# 10

# %%
anime_df["title"][1]
# Out:
# uid
# 1    Cowboy Bebop
# 1    Cowboy Bebop
# Name: title, dtype: object

# %%
# Make list from outputs; join anime title to encoding list index

# Make a for-loop to identify top 5 most similar anime

# %%
# Append top 5 most similar amime to each movie as new column in movie df
